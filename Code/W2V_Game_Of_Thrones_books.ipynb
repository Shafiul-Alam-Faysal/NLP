# %%
import numpy as np
import pandas as pd

# %%
# pip install gensim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gensim
#   Downloading gensim-4.4.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /home/vscode/.local/lib/python3.11/site-packages (from gensim) (2.4.4)
# Requirement already satisfied: scipy>=1.7.0 in /home/vscode/.local/lib/python3.11/site-packages (from gensim) (1.17.1)
# Requirement already satisfied: smart_open>=1.8.1 in /home/vscode/.local/lib/python3.11/site-packages (from gensim) (7.6.1)
# Requirement already satisfied: wrapt in /home/vscode/.local/lib/python3.11/site-packages (from smart_open>=1.8.1->gensim) (2.2.1)
# Downloading gensim-4.4.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.8/27.8 MB 3.5 MB/s  0:00:07m0:00:0100:01
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import gensim
import os

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
story = []

folder = "../Dataset/Game Of Thrones books"

for filename in os.listdir(folder):
    f = open(os.path.join(folder, filename),"r", encoding="cp1252")
    corpus = f.read()
    raw_sent = sent_tokenize(corpus)
    for sent in raw_sent:
        story.append(simple_preprocess(sent))

# %%
len(story)
# Out:
# 145025

# %%
story

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2, 
    
)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (6571090, 8628490)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('stormborn', 0.7755235433578491),
#  ('targaryen', 0.7674009799957275),
#  ('queen', 0.7268210053443909),
#  ('unburnt', 0.7252753973007202),
#  ('myrcella', 0.7168365120887756),
#  ('princess', 0.7111930251121521),
#  ('viserys', 0.6764781475067139),
#  ('elia', 0.6735295653343201),
#  ('dorne', 0.6595583558082581),
#  ('margaery', 0.6552777290344238)]

# %%
model.wv['jon']
# Out:
# array([-0.40449762, -2.5898287 ,  0.31599712, -1.0293347 ,  1.5209522 ,
#         1.2442888 ,  0.20786433,  0.56248707, -0.49022183, -0.18296303,
#        -0.6809415 , -0.71092415, -0.53467494, -2.2832084 , -0.39240834,
#        -0.00431672,  0.26284543,  3.7834477 , -0.04551793, -1.5220308 ,
#         2.4992986 , -1.6887394 ,  0.01405824,  1.339524  , -1.4625732 ,
#        -1.2768695 , -0.26347736,  0.39599624, -0.37098414, -0.43539947,
#        -1.1783988 , -1.3448908 ,  1.2603607 , -1.869655  ,  0.5788488 ,
#         1.2558078 ,  1.5097197 ,  0.5901451 ,  1.686588  , -1.0354749 ,
#        -0.4670217 , -2.4277256 ,  1.4427115 ,  1.995895  ,  1.5887018 ,
#        -1.7490335 , -0.15545535,  0.27001932, -0.29491228, -0.8092236 ,
#         0.32555237, -0.32715473,  2.035437  ,  0.31331456, -0.0051982 ,
#         0.6967905 , -0.33484232, -1.4197793 , -0.67986834, -0.32752568,
#        -0.5166114 ,  1.4435952 ,  2.9700627 , -1.5197097 ,  0.93266195,
#         0.43174773,  0.58048666,  2.9718823 , -1.0525267 ,  0.92989165,
#         1.9377238 , -0.13533013,  0.35112432, -0.6127939 ,  0.24430084,
#         2.1314073 , -2.0260332 ,  3.1348286 ,  0.23756522,  0.4478722 ,
#        -1.0463908 , -2.5328424 , -0.886969  , -0.06790683, -2.3438702 ,
#         0.96157813, -1.296067  , -1.6317453 ,  0.42760596, -2.1243422 ,
#        -0.13007131,  0.75743264,  2.8619843 ,  0.16934347,  0.9790368 ,
#        -1.4443297 ,  0.04770332, -0.95643115,  1.0779592 ,  1.0524497 ],
#       dtype=float32)

# %%
model.wv['jon'].shape
# Out:
# (100,)

# %%
model.wv.get_normed_vectors()
# Out:
# array([[ 1.5881240e-02, -9.6451752e-02,  1.4032577e-01, ...,
#         -1.5260105e-01,  4.2093020e-02,  5.8118388e-02],
#        [-8.3671860e-02, -3.5913993e-02,  4.8184235e-02, ...,
#          1.1212042e-01, -1.1882519e-01,  1.0003954e-01],
#        [ 5.2016944e-02, -5.6596197e-02, -8.3636723e-02, ...,
#          8.9665315e-05,  6.4668156e-02, -6.4568542e-02],
#        ...,
#        [ 7.3522860e-03, -2.7292490e-03,  1.2058753e-01, ...,
#         -3.7876658e-02,  2.7589234e-02,  1.0077720e-02],
#        [-3.0702347e-02,  7.4197441e-02,  1.2364696e-01, ...,
#         -1.7409374e-01,  9.9212639e-02,  8.1735335e-02],
#        [ 1.4889023e-01, -2.6879909e-02,  1.2944199e-01, ...,
#          5.0273154e-02,  2.0648083e-01, -7.3845468e-02]],
#       shape=(17464, 100), dtype=float32)

# %%
model.wv.get_normed_vectors().shape
# Out:
# (17464, 100)

# %%
y = model.wv.index_to_key

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
X = pca.fit_transform(model.wv.get_normed_vectors())

# %%
import plotly.express as px
fig = px.scatter_3d(X[:100], x=0,y=1,z=2, color=y[:100])
fig.show()
